# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *Unit of Analysis: One row represents one unique piece of content (content_id) for a specific client (client_hash_id), aggregated over a single month.
#
# Time Window: We will use March 2026 (2026-03) as our training and iteration month. We are deliberately excluding the final month (June 2026 / _sample table) to use it as a sealed test set and prevent data leakage.*

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Features (Inputs): search_volume, competition_level, position_tier, main_intent.
#
# Label (Target): expected_ctr (derived from organic clicks / impressions).
#
# Context (Identifiers): content_id, client_hash_id, month.
#
# Excluded (and why):
# engaged_sessions_90d: This metric happens after the user clicks the link. If we use it to predict the click itself, it creates data leakage (cheating).
# cpc (Cost Per Click): This is a paid advertising metric and is irrelevant for predicting organic SEO click-through rates.*

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
from google.colab import userdata

# 1. HF_TOKEN'ı kasadan çağırıyoruz
hf_token = userdata.get('HF_TOKEN')
print("Başarılı: HF_TOKEN kasadan güvenle okundu ve Hugging Face bağlantısı hazır!\n")

# 2. Sözleşme Kanıtları (Contract Facts)
print("--- 3 KANIT (FACTS) ---")
print("1. Grain: Her satır tek bir 'content_id' ve 'client_hash_id' kombinasyonunu temsil ediyor.")
print("2. Date Span: Veri '2026-03' (Mart 2026) ayına sabitlendi.")
print("3. Availability: Sadece 'is_active == TRUE' olan içerikler filtrelendi.\n")

# 3. Özellikler ve Tuzak (Features & The Trap)
print("--- ÖZELLİKLER VE VERİ SIZINTISI TUZAĞI ---")
print("Seçilen 5 Feature: search_volume, competition_level, position_tier, main_intent, word_count")
print("TUZAĞA DÜŞÜŞ: Modele 'clicks_90d' (gerçek tıklama sayısı) sütununu eklersek, model 'Beklenen CTR'ı %100 doğru tahmin eder. Çünkü sonucu zaten vermiş oluruz (Data Leakage).")
print("MÜDAHALE: Hileli sütun tespit edildi ve dürüst bir model için eğitim setinden kaldırıldı.")
# Out:
# Başarılı: HF_TOKEN kasadan güvenle okundu ve Hugging Face bağlantısı hazır!
#
# --- 3 KANIT (FACTS) ---
# 1. Grain: Her satır tek bir 'content_id' ve 'client_hash_id' kombinasyonunu temsil ediyor.
# 2. Date Span: Veri '2026-03' (Mart 2026) ayına sabitlendi.
# 3. Availability: Sadece 'is_active == TRUE' olan içerikler filtrelendi.
#
# --- ÖZELLİKLER VE VERİ SIZINTISI TUZAĞI ---
# Seçilen 5 Feature: search_volume, competition_level, position_tier, main_intent, word_count
# TUZAĞA DÜŞÜŞ: Modele 'clicks_90d' (gerçek tıklama sayısı) sütununu eklersek, model 'Beklenen CTR'ı %100 doğru tahmin eder. Çünkü sonucu zaten vermiş oluruz (Data Leakage).
# MÜDAHALE: Hileli sütun tespit edildi ve dürüst bir model için eğitim setinden kaldırıldı.

# %% [markdown]
# ## 4. Data limits
#
# *Data Limits: This dataset can never tell us the full historical context for all clients equally. We have an unbalanced history because clients integrated their systems at different times. Additionally, some early rows are GSC-only (Google Search Console), meaning they lack matching GA4 behavioral data (like engaged sessions) for those older dates.*

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
